# %% [markdown]
# #### Demographics and Employment in the US
# The government measures unemployment using the Current Population Survey (CPS). In this exercise, we will use a compact form of the September 2013 version of this rich, nationally representative dataset (usually available online).

# %%
##set up
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
#Read in data:
data=pd.read_csv('CPSData.csv')
data.head()
# Out:
#    PeopleInHousehold Region    State  MetroAreaCode  Age        Married  \
# 0                  1  South  Alabama        26620.0   85        Widowed
# 1                  3  South  Alabama        13820.0   21  Never Married
# 2                  3  South  Alabama        13820.0   37  Never Married
# 3                  3  South  Alabama        13820.0   18  Never Married
# 4                  3  South  Alabama        26620.0   52        Widowed
#
#       Sex               Education   Race  Hispanic  CountryOfBirthCode  \
# 0  Female        Associate degree  White         0                  57
# 1    Male             High school  Black         0                  57
# 2  Female             High school  Black         0                  57
# 3    Male  No high school diploma  Black         0                  57
# 4  Female        Associate degree  White         0                  57
#
#        Citizenship    EmploymentStatus                            Industry
# 0  Citizen, Native             Retired                                 NaN
# 1  Citizen, Native          Unemployed  Professional and business services
# 2  Citizen, Native            Disabled                                 NaN
# 3  Citizen, Native  Not in Labor Force                                 NaN
# 4  Citizen, Native            Employed  Professional and business services

# %% [markdown]
# #### How many interviewees int his dataset?
# Among the interviewees with a value reported for the Industry variable, what is the most common industry of employment?

# %%
data.shape
# Out:
# (131302, 14)

# %%
data.Industry.value_counts()
# Out:
# Educational and health services                15017
# Trade                                           8933
# Professional and business services              7519
# Manufacturing                                   6791
# Leisure and hospitality                         6364
# Construction                                    4387
# Financial                                       4347
# Transportation and utilities                    3260
# Other services                                  3224
# Public administration                           3186
# Information                                     1328
# Agriculture, forestry, fishing, and hunting     1307
# Mining                                           550
# Armed forces                                      29
# Name: Industry, dtype: int64

# %% [markdown]
# #### * Which state has the fewest interviewees?
# #### * Which state has the largest number of interviewees?
# #### * What proportion of interviewees are citizens of the United States?

# %%
(data.groupby('State').count())['Region'].sort_values()
# Out:
# State
# New Mexico               1102
# Montana                  1214
# Mississippi              1230
# Alabama                  1376
# West Virginia            1409
# Arkansas                 1421
# Louisiana                1450
# Idaho                    1518
# Oklahoma                 1523
# Arizona                  1528
# Alaska                   1590
# Wyoming                  1624
# North Dakota             1645
# South Carolina           1658
# Tennessee                1784
# District of Columbia     1791
# Kentucky                 1841
# Utah                     1842
# Nevada                   1856
# Vermont                  1890
# Kansas                   1935
# Oregon                   1943
# Nebraska                 1949
# Massachusetts            1987
# South Dakota             2000
# Indiana                  2004
# Hawaii                   2099
# Missouri                 2145
# Rhode Island             2209
# Delaware                 2214
# Maine                    2263
# Washington               2366
# Iowa                     2528
# New Jersey               2567
# North Carolina           2619
# New Hampshire            2662
# Wisconsin                2686
# Georgia                  2807
# Connecticut              2836
# Colorado                 2925
# Virginia                 2953
# Michigan                 3063
# Minnesota                3139
# Maryland                 3200
# Ohio                     3678
# Illinois                 3912
# Pennsylvania             3930
# Florida                  5149
# New York                 5595
# Texas                    7077
# California              11570
# Name: Region, dtype: int64

# %% [markdown]
# * Least- New Mexico
# * Largest num of Interviewees: California

# %%
(data['Citizenship'].value_counts())
float(116639+7073)/131302
# Out:
# 0.9421943306271039

# %% [markdown]
# Citizens are 94.2% of the data.

# %% [markdown]
# #### The CPS differentiates between race (with possible values American Indian, Asian, Black, Pacific Islander, White, or Multiracial) and ethnicity. A number of interviewees are of Hispanic ethnicity, as captured by the Hispanic variable. For which races are there at least 250 interviewees in the CPS dataset of Hispanic ethnicity?

# %%
data.groupby('Race')['Hispanic'].sum()
#data['Hispanic']
# Out:
# Race
# American Indian       304
# Asian                 113
# Black                 621
# Multiracial           448
# Pacific Islander       77
# White               16731
# Name: Hispanic, dtype: int64

# %% [markdown]
# #### Which variables have at least one interviewee with a missing (NA) value?

# %%
data.isnull().sum()
# Out:
# PeopleInHousehold         0
# Region                    0
# State                     0
# MetroAreaCode         34238
# Age                       0
# Married               25338
# Sex                       0
# Education             25338
# Race                      0
# Hispanic                  0
# CountryOfBirthCode        0
# Citizenship               0
# EmploymentStatus      25789
# Industry              65060
# dtype: int64

# %% [markdown]
# #### Evaluating Missing Values:
# Lets try to determine if there is a pattern in the missing values of the Married variable. Lets try grouping it by different variables

# %%
data.groupby('Region')['Married'].value_counts()
# Out:
# Region     Married
# Midwest    Married          13272
#            Never Married     6869
#            Divorced          2630
#            Widowed           1505
#            Separated          333
# Northeast  Married          11078
#            Never Married     6508
#            Divorced          2122
#            Widowed           1332
#            Separated          392
# South      Married          17301
#            Never Married     9606
#            Divorced          3586
#            Widowed           2221
#            Separated          821
# West       Married          13858
#            Never Married     7789
#            Divorced          2813
#            Widowed           1447
#            Separated          481
# Name: Married, dtype: int64

# %%
###Aah...but what I need is to group ONLY the null values of Married by region..
##NOTE: I cannot use the column married  as he its values are NAN and so the count..gives me 0
##So any other field will work..
(data[data.Married.isnull()]).groupby('Region')['Sex'].count()
# Out:
# Region
# Midwest      6075
# Northeast    4507
# South        7967
# West         6789
# Name: Sex, dtype: int64

# %%
(data[data.Married.isnull()]).groupby('Region')['PeopleInHousehold'].count()
# Out:
# Region
# Midwest      6075
# Northeast    4507
# South        7967
# West         6789
# Name: PeopleInHousehold, dtype: int64

# %%
data[data['Married'].isnull()].groupby('Sex')['Region'].count()
# Out:
# Sex
# Female    12217
# Male      13121
# Name: Region, dtype: int64

# %%
data[data.Married.isnull()].groupby('Age')['Region'].count()
# Out:
# Age
# 0     1283
# 1     1559
# 2     1574
# 3     1693
# 4     1695
# 5     1795
# 6     1721
# 7     1681
# 8     1729
# 9     1748
# 10    1750
# 11    1721
# 12    1797
# 13    1802
# 14    1790
# Name: Region, dtype: int64

# %%
data[data.Married.isnull()]
# Out:
#         PeopleInHousehold Region    State  MetroAreaCode  Age Married     Sex  \
# 13                      4  South  Alabama        26620.0    2     NaN  Female
# 14                      4  South  Alabama        26620.0    4     NaN    Male
# 17                      2  South  Alabama        13820.0   13     NaN  Female
# 27                      3  South  Alabama        33860.0    2     NaN  Female
# 34                      6  South  Alabama        33860.0    3     NaN  Female
# 35                      6  South  Alabama        33860.0   11     NaN  Female
# 47                      2  South  Alabama        26620.0    5     NaN    Male
# 50                      4  South  Alabama        33660.0   14     NaN    Male
# 56                      3  South  Alabama        13820.0    5     NaN    Male
# 57                      3  South  Alabama        13820.0   11     NaN  Female
# 59                      5  South  Alabama        33860.0    9     NaN    Male
# 60                      5  South  Alabama        33860.0   12     NaN  Female
# 61                      5  South  Alabama        33860.0   14     NaN    Male
# 84                      5  South  Alabama        13820.0   10     NaN    Male
# 85                      5  South  Alabama        13820.0   10     NaN    Male
# 91                      3  South  Alabama        26620.0    9     NaN    Male
# 99                      2  South  Alabama        26620.0    1     NaN  Female
# 123                     3  South  Alabama        33860.0    3     NaN    Male
# 136                     4  South  Alabama        33660.0   14     NaN  Female
# 149                     3  South  Alabama        33660.0    2     NaN    Male
# 169                     2  South  Alabama        13820.0    1     NaN  Female
# 188                     5  South  Alabama        33660.0    1     NaN    Male
# 189                     5  South  Alabama        33660.0    4     NaN  Female
# 190                     5  South  Alabama        33660.0    7     NaN  Female
# 193                     3  South  Alabama        13820.0    6     NaN  Female
# 202                     4  South  Alabama        26620.0    3     NaN    Male
# 203                     4  South  Alabama        26620.0    5     NaN    Male
# 204                     4  South  Alabama        26620.0    8     NaN  Female
# 212                     2  South  Alabama        33660.0    9     NaN  Female
# 228                     3  South  Alabama        13820.0    6     NaN  Female
# ...                   ...    ...      ...            ...  ...     ...     ...
# 131174                  5   West  Wyoming            NaN   11     NaN    Male
# 131177                  4   West  Wyoming            NaN    7     NaN    Male
# 131182                  5   West  Wyoming            NaN    8     NaN  Female
# 131183                  5   West  Wyoming            NaN   11     NaN    Male
# 131184                  5   West  Wyoming            NaN   14     NaN  Female
# 131189                  4   West  Wyoming            NaN   10     NaN  Female
# 131190                  4   West  Wyoming            NaN   12     NaN  Female
# 131197                  3   West  Wyoming            NaN    2     NaN    Male
# 131200                  4   West  Wyoming            NaN   14     NaN    Male
# 131205                  4   West  Wyoming            NaN    4     NaN  Female
# 131206                  4   West  Wyoming            NaN    7     NaN    Male
# 131209                  4   West  Wyoming            NaN    1     NaN    Male
# 131210                  4   West  Wyoming            NaN    5     NaN    Male
# 131211                  4   West  Wyoming            NaN   14     NaN    Male
# 131222                  3   West  Wyoming            NaN   12     NaN    Male
# 131232                  3   West  Wyoming            NaN    9     NaN    Male
# 131233                  3   West  Wyoming            NaN   12     NaN  Female
# 131240                  6   West  Wyoming            NaN   13     NaN  Female
# 131241                  6   West  Wyoming            NaN   14     NaN  Female
# 131250                  4   West  Wyoming            NaN    6     NaN    Male
# 131251                  4   West  Wyoming            NaN    7     NaN  Female
# 131261                  4   West  Wyoming            NaN   10     NaN  Female
# 131275                  4   West  Wyoming            NaN    9     NaN  Female
# 131276                  4   West  Wyoming            NaN   11     NaN  Female
# 131280                  5   West  Wyoming            NaN   13     NaN  Female
# 131281                  5   West  Wyoming            NaN    4     NaN  Female
# 131282                  5   West  Wyoming            NaN    9     NaN  Female
# 131295                  5   West  Wyoming            NaN   10     NaN  Female
# 131296                  5   West  Wyoming            NaN   14     NaN    Male
# 131301                  3   West  Wyoming            NaN   14     NaN  Female
#
#        Education             Race  Hispanic  CountryOfBirthCode  \
# 13           NaN            White         0                  57
# 14           NaN            White         0                  57
# 17           NaN            Black         0                  57
# 27           NaN            White         0                  57
# 34           NaN            Black         0                  57
# 35           NaN            Black         0                  57
# 47           NaN            Black         0                  57
# 50           NaN            White         0                  57
# 56           NaN            Black         0                  57
# 57           NaN            Black         0                  57
# 59           NaN            Black         0                  57
# 60           NaN            Black         0                  57
# 61           NaN            Black         0                  57
# 84           NaN            White         0                  57
# 85           NaN            White         0                  57
# 91           NaN            White         0                  57
# 99           NaN            Black         0                  57
# 123          NaN            White         0                  57
# 136          NaN            Black         0                  57
# 149          NaN            White         0                  57
# 169          NaN            Black         0                  57
# 188          NaN            Black         0                  57
# 189          NaN            Black         0                  57
# 190          NaN            Black         0                  57
# 193          NaN            Black         0                  57
# 202          NaN            White         0                  57
# 203          NaN            White         0                  57
# 204          NaN            White         0                  57
# 212          NaN            Black         0                  57
# 228          NaN            Black         0                  57
# ...          ...              ...       ...                 ...
# 131174       NaN            White         0                  57
# 131177       NaN            White         0                  57
# 131182       NaN            White         0                  57
# 131183       NaN            White         0                  57
# 131184       NaN            White         0                  57
# 131189       NaN            White         0                  57
# 131190       NaN            White         0                  57
# 131197       NaN            White         0                  57
# 131200       NaN            White         0                  57
# 131205       NaN            White         0                  57
# 131206       NaN            White         0                  57
# 131209       NaN  American Indian         0                  57
# 131210       NaN  American Indian         0                  57
# 131211       NaN  American Indian         0                  57
# 131222       NaN            White         0                  57
# 131232       NaN            White         1                  57
# 131233       NaN            White         1                  57
# 131240       NaN            White         1                  57
# 131241       NaN            White         1                  57
# 131250       NaN            White         0                  57
# 131251       NaN            White         0                  57
# 131261       NaN            White         0                  57
# 131275       NaN            White         1                  57
# 131276       NaN            White         1                  57
# 131280       NaN            White         0                  57
# 131281       NaN            White         0                  57
# 131282       NaN            White         0                  57
# 131295       NaN            White         0                  57
# 131296       NaN            White         0                  57
# 131301       NaN            White         0                  57
#
#             Citizenship EmploymentStatus Industry
# 13      Citizen, Native              NaN      NaN
# 14      Citizen, Native              NaN      NaN
# 17      Citizen, Native              NaN      NaN
# 27      Citizen, Native              NaN      NaN
# 34      Citizen, Native              NaN      NaN
# 35      Citizen, Native              NaN      NaN
# 47      Citizen, Native              NaN      NaN
# 50      Citizen, Native              NaN      NaN
# 56      Citizen, Native              NaN      NaN
# 57      Citizen, Native              NaN      NaN
# 59      Citizen, Native              NaN      NaN
# 60      Citizen, Native              NaN      NaN
# 61      Citizen, Native              NaN      NaN
# 84      Citizen, Native              NaN      NaN
# 85      Citizen, Native              NaN      NaN
# 91      Citizen, Native              NaN      NaN
# 99      Citizen, Native              NaN      NaN
# 123     Citizen, Native              NaN      NaN
# 136     Citizen, Native              NaN      NaN
# 149     Citizen, Native              NaN      NaN
# 169     Citizen, Native              NaN      NaN
# 188     Citizen, Native              NaN      NaN
# 189     Citizen, Native              NaN      NaN
# 190     Citizen, Native              NaN      NaN
# 193     Citizen, Native              NaN      NaN
# 202     Citizen, Native              NaN      NaN
# 203     Citizen, Native              NaN      NaN
# 204     Citizen, Native              NaN      NaN
# 212     Citizen, Native              NaN      NaN
# 228     Citizen, Native              NaN      NaN
# ...                 ...              ...      ...
# 131174  Citizen, Native              NaN      NaN
# 131177  Citizen, Native              NaN      NaN
# 131182  Citizen, Native              NaN      NaN
# 131183  Citizen, Native              NaN      NaN
# 131184  Citizen, Native              NaN      NaN
# 131189  Citizen, Native              NaN      NaN
# 131190  Citizen, Native              NaN      NaN
# 131197  Citizen, Native              NaN      NaN
# 131200  Citizen, Native              NaN      NaN
# 131205  Citizen, Native              NaN      NaN
# 131206  Citizen, Native              NaN      NaN
# 131209  Citizen, Native              NaN      NaN
# 131210  Citizen, Native              NaN      NaN
# 131211  Citizen, Native              NaN      NaN
# 131222  Citizen, Native              NaN      NaN
# 131232  Citizen, Native              NaN      NaN
# 131233  Citizen, Native              NaN      NaN
# 131240  Citizen, Native              NaN      NaN
# 131241  Citizen, Native              NaN      NaN
# 131250  Citizen, Native              NaN      NaN
# 131251  Citizen, Native              NaN      NaN
# 131261  Citizen, Native              NaN      NaN
# 131275  Citizen, Native              NaN      NaN
# 131276  Citizen, Native              NaN      NaN
# 131280  Citizen, Native              NaN      NaN
# 131281  Citizen, Native              NaN      NaN
# 131282  Citizen, Native              NaN      NaN
# 131295  Citizen, Native              NaN      NaN
# 131296  Citizen, Native              NaN      NaN
# 131301  Citizen, Native              NaN      NaN
#
# [25338 rows x 14 columns]

# %%
data[data.Married.isnull()].groupby('Citizenship')['Region'].count()
# Out:
# Citizenship
# Citizen, Native         24683
# Citizen, Naturalized      163
# Non-Citizen               492
# Name: Region, dtype: int64

# %% [markdown]
# #### So Marriage variable is missing for all interviewees between the age 0-14

# %% [markdown]
# #### MetroAreaCode is missing if an interviewee does not live in a metropolitan area.
# * How many states had all interviewees living in a non-metropolitan area (aka they have a missing MetroAreaCode value)? For this question, treat the District of Columbia as a state (even though it is not technically a state).
# * How many states had all interviewees living in a metropolitan area? Again, treat the District of Columbia as a state.
# *

# %%
data[data.MetroAreaCode.isnull()].groupby('State').count()
# Out:
#                 PeopleInHousehold  Region  MetroAreaCode   Age  Married   Sex  \
# State
# Alabama                       356     356              0   356      300   356
# Alaska                       1590    1590              0  1590     1246  1590
# Arizona                       201     201              0   201      162   201
# Arkansas                      697     697              0   697      548   697
# California                    237     237              0   237      185   237
# Colorado                      380     380              0   380      305   380
# Connecticut                   243     243              0   243      203   243
# Delaware                      518     518              0   518      449   518
# Florida                       202     202              0   202      172   202
# Georgia                       557     557              0   557      433   557
# Hawaii                        523     523              0   523      400   523
# Idaho                         757     757              0   757      586   757
# Illinois                      439     439              0   439      345   439
# Indiana                       584     584              0   584      484   584
# Iowa                         1231    1231              0  1231     1026  1231
# Kansas                        701     701              0   701      574   701
# Kentucky                      933     933              0   933      782   933
# Louisiana                     234     234              0   234      185   234
# Maine                        1354    1354              0  1354     1119  1354
# Maryland                      222     222              0   222      177   222
# Massachusetts                 129     129              0   129      110   129
# Michigan                      546     546              0   546      451   546
# Minnesota                     989     989              0   989      788   989
# Mississippi                   854     854              0   854      696   854
# Missouri                      705     705              0   705      561   705
# Montana                      1015    1015              0  1015      852  1015
# Nebraska                     1133    1133              0  1133      925  1133
# Nevada                        247     247              0   247      202   247
# New Hampshire                1514    1514              0  1514     1275  1514
# New Mexico                    270     270              0   270      207   270
# New York                      451     451              0   451      363   451
# North Carolina                977     977              0   977      805   977
# North Dakota                 1213    1213              0  1213      992  1213
# Ohio                          924     924              0   924      752   924
# Oklahoma                      499     499              0   499      386   499
# Oregon                        424     424              0   424      347   424
# Pennsylvania                  685     685              0   685      580   685
# South Carolina                519     519              0   519      445   519
# South Dakota                 1405    1405              0  1405     1131  1405
# Tennessee                     635     635              0   635      529   635
# Texas                        1017    1017              0  1017      774  1017
# Utah                          387     387              0   387      271   387
# Vermont                      1233    1233              0  1233     1045  1233
# Virginia                      586     586              0   586      485   586
# Washington                    429     429              0   429      358   429
# West Virginia                1065    1065              0  1065      898  1065
# Wisconsin                     804     804              0   804      641   804
# Wyoming                      1624    1624              0  1624     1297  1624
#
#                 Education  Race  Hispanic  CountryOfBirthCode  Citizenship  \
# State
# Alabama               300   356       356                 356          356
# Alaska               1246  1590      1590                1590         1590
# Arizona               162   201       201                 201          201
# Arkansas              548   697       697                 697          697
# California            185   237       237                 237          237
# Colorado              305   380       380                 380          380
# Connecticut           203   243       243                 243          243
# Delaware              449   518       518                 518          518
# Florida               172   202       202                 202          202
# Georgia               433   557       557                 557          557
# Hawaii                400   523       523                 523          523
# Idaho                 586   757       757                 757          757
# Illinois              345   439       439                 439          439
# Indiana               484   584       584                 584          584
# Iowa                 1026  1231      1231                1231         1231
# Kansas                574   701       701                 701          701
# Kentucky              782   933       933                 933          933
# Louisiana             185   234       234                 234          234
# Maine                1119  1354      1354                1354         1354
# Maryland              177   222       222                 222          222
# Massachusetts         110   129       129                 129          129
# Michigan              451   546       546                 546          546
# Minnesota             788   989       989                 989          989
# Mississippi           696   854       854                 854          854
# Missouri              561   705       705                 705          705
# Montana               852  1015      1015                1015         1015
# Nebraska              925  1133      1133                1133         1133
# Nevada                202   247       247                 247          247
# New Hampshire        1275  1514      1514                1514         1514
# New Mexico            207   270       270                 270          270
# New York              363   451       451                 451          451
# North Carolina        805   977       977                 977          977
# North Dakota          992  1213      1213                1213         1213
# Ohio                  752   924       924                 924          924
# Oklahoma              386   499       499                 499          499
# Oregon                347   424       424                 424          424
# Pennsylvania          580   685       685                 685          685
# South Carolina        445   519       519                 519          519
# South Dakota         1131  1405      1405                1405         1405
# Tennessee             529   635       635                 635          635
# Texas                 774  1017      1017                1017         1017
# Utah                  271   387       387                 387          387
# Vermont              1045  1233      1233                1233         1233
# Virginia              485   586       586                 586          586
# Washington            358   429       429                 429          429
# West Virginia         898  1065      1065                1065         1065
# Wisconsin             641   804       804                 804          804
# Wyoming              1297  1624      1624                1624         1624
#
#                 EmploymentStatus  Industry
# State
# Alabama                      299       136
# Alaska                      1211       824
# Arizona                      161        89
# Arkansas                     548       296
# California                   185       101
# Colorado                     305       203
# Connecticut                  203       127
# Delaware                     447       231
# Florida                      172        91
# Georgia                      431       228
# Hawaii                       400       243
# Idaho                        585       363
# Illinois                     345       215
# Indiana                      483       289
# Iowa                        1022       653
# Kansas                       567       392
# Kentucky                     779       393
# Louisiana                    185       102
# Maine                       1113       703
# Maryland                     175        95
# Massachusetts                110        72
# Michigan                     451       225
# Minnesota                    788       516
# Mississippi                  693       331
# Missouri                     560       350
# Montana                      849       526
# Nebraska                     923       637
# Nevada                       202       127
# New Hampshire               1274       851
# New Mexico                   205       103
# New York                     363       215
# North Carolina               805       425
# North Dakota                 985       710
# Ohio                         749       464
# Oklahoma                     384       211
# Oregon                       345       193
# Pennsylvania                 579       331
# South Carolina               444       232
# South Dakota                1124       723
# Tennessee                    524       283
# Texas                        772       460
# Utah                         271       174
# Vermont                     1043       698
# Virginia                     483       284
# Washington                   357       204
# West Virginia                897       469
# Wisconsin                    640       414
# Wyoming                     1291       844

# %%
data[data.MetroAreaCode.isnull()].groupby('State')['State'].count()
# Out:
# State
# Alabama            356
# Alaska            1590
# Arizona            201
# Arkansas           697
# California         237
# Colorado           380
# Connecticut        243
# Delaware           518
# Florida            202
# Georgia            557
# Hawaii             523
# Idaho              757
# Illinois           439
# Indiana            584
# Iowa              1231
# Kansas             701
# Kentucky           933
# Louisiana          234
# Maine             1354
# Maryland           222
# Massachusetts      129
# Michigan           546
# Minnesota          989
# Mississippi        854
# Missouri           705
# Montana           1015
# Nebraska          1133
# Nevada             247
# New Hampshire     1514
# New Mexico         270
# New York           451
# North Carolina     977
# North Dakota      1213
# Ohio               924
# Oklahoma           499
# Oregon             424
# Pennsylvania       685
# South Carolina     519
# South Dakota      1405
# Tennessee          635
# Texas             1017
# Utah               387
# Vermont           1233
# Virginia           586
# Washington         429
# West Virginia     1065
# Wisconsin          804
# Wyoming           1624
# Name: State, dtype: int64

# %%
metroisnull=list(data[data.MetroAreaCode.isnull()].groupby('State')['State'].count().index)

# %%
metroisnull
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
metroisnotnull= list(data[data.MetroAreaCode.isnull() == False].groupby('State')['State'].count().index)
allstates=list(pd.unique(data.State))
len(allstates)
# Out:
# 51

# %%
state_whereallareurban=set(allstates)-set(metroisnull)
state_whereallareurban
# Out:
# {'District of Columbia', 'New Jersey', 'Rhode Island'}

# %%
states_where_all_are_rural=set(allstates)-set(metroisnotnull)
states_where_all_are_rural
# Out:
# {'Alaska', 'Wyoming'}

# %% [markdown]
# #### Evaluating Missing Values
# Which region of the United States has the largest proportion of interviewees living in a non-metropolitan area?

# %%
rur= (data[data.MetroAreaCode.isnull()]).groupby('Region')['State'].count()
rur
# Out:
# Region
# Midwest      10674
# Northeast     5609
# South         9871
# West          8084
# Name: State, dtype: int64

# %%
all=data.groupby('Region')['State'].count()

# %%
rur/all
# Out:
# Region
# Midwest      0.347869
# Northeast    0.216238
# South        0.237844
# West         0.243663
# Name: State, dtype: float64

# %% [markdown]
# #### Perhaps an easier way??
# * Which STATE has a proportion of interviewees living in a non-metropolitan area closest to 30%?
# * Which state has the largest proportion of non-metropolitan interviewees, ignoring states where all interviewees were non-metropolitan?

# %%
(data[data.MetroAreaCode.isnull()]).groupby('State').size()/((data[data.MetroAreaCode.isnull()]).groupby('State').size()+(data[data.MetroAreaCode.isnull()==False]).groupby('State').size())
# Out:
# State
# Alabama                 0.258721
# Alaska                       NaN
# Arizona                 0.131545
# Arkansas                0.490500
# California              0.020484
# Colorado                0.129915
# Connecticut             0.085684
# Delaware                0.233966
# District of Columbia         NaN
# Florida                 0.039231
# Georgia                 0.198432
# Hawaii                  0.249166
# Idaho                   0.498682
# Illinois                0.112219
# Indiana                 0.291417
# Iowa                    0.486946
# Kansas                  0.362274
# Kentucky                0.506790
# Louisiana               0.161379
# Maine                   0.598321
# Maryland                0.069375
# Massachusetts           0.064922
# Michigan                0.178257
# Minnesota               0.315068
# Mississippi             0.694309
# Missouri                0.328671
# Montana                 0.836079
# Nebraska                0.581324
# Nevada                  0.133082
# New Hampshire           0.568745
# New Jersey                   NaN
# New Mexico              0.245009
# New York                0.080608
# North Carolina          0.373043
# North Dakota            0.737386
# Ohio                    0.251223
# Oklahoma                0.327643
# Oregon                  0.218219
# Pennsylvania            0.174300
# Rhode Island                 NaN
# South Carolina          0.313028
# South Dakota            0.702500
# Tennessee               0.355942
# Texas                   0.143705
# Utah                    0.210098
# Vermont                 0.652381
# Virginia                0.198442
# Washington              0.181319
# West Virginia           0.755855
# Wisconsin               0.299330
# Wyoming                      NaN
# dtype: float64

# %% [markdown]
# #### Integrating Metropolitan Area Data
# When analyzing a variable stored by a numeric code, we will often want to convert it into the values the codes represent. To do this, we will use a dictionary, which maps the the code to the actual value of the variable. We have provided dictionaries MetroAreaCodes.csv and CountryCodes.csv, which respectively map MetroAreaCode and CountryOfBirthCode into their true values. Read these two dictionaries into data frames MetroAreaMap and CountryMap.
#
# To merge in the metropolitan areas, we want to connect the field MetroAreaCode from the CPS data frame with the field Code in MetroAreaMap

# %%
metroAC=pd.read_csv('MetroAreaCodes.csv')
cc=pd.read_csv('CountryCodes.csv')
metroAC.shape
# Out:
# (271, 2)

# %%
cc.shape
# Out:
# (149, 2)

# %%
metroAC.head()
# Out:
#    Code                            MetroArea
# 0   460          Appleton-Oshkosh-Neenah, WI
# 1  3000    Grand Rapids-Muskegon-Holland, MI
# 2  3160  Greenville-Spartanburg-Anderson, SC
# 3  3610                        Jamestown, NY
# 4  3720           Kalamazoo-Battle Creek, MI

# %%
cc.head()
# Out:
#    Code                   Country
# 0    57             United States
# 1    66                      Guam
# 2    73               Puerto Rico
# 3    78      U. S. Virgin Islands
# 4    96  Other U. S. Island Areas

# %%
data.head(2)
# Out:
#    PeopleInHousehold Region    State  MetroAreaCode  Age        Married  \
# 0                  1  South  Alabama        26620.0   85        Widowed
# 1                  3  South  Alabama        13820.0   21  Never Married
#
#       Sex         Education   Race  Hispanic  CountryOfBirthCode  \
# 0  Female  Associate degree  White         0                  57
# 1    Male       High school  Black         0                  57
#
#        Citizenship EmploymentStatus                            Industry
# 0  Citizen, Native          Retired                                 NaN
# 1  Citizen, Native       Unemployed  Professional and business services

# %%
##merge the data frames:
tmp=data.merge(metroAC,how='left',left_on='MetroAreaCode',right_on='Code',sort=False )
tmp.head(3)
# Out:
#    PeopleInHousehold Region    State  MetroAreaCode  Age        Married  \
# 0                  1  South  Alabama        26620.0   85        Widowed
# 1                  3  South  Alabama        13820.0   21  Never Married
# 2                  3  South  Alabama        13820.0   37  Never Married
#
#       Sex         Education   Race  Hispanic  CountryOfBirthCode  \
# 0  Female  Associate degree  White         0                  57
# 1    Male       High school  Black         0                  57
# 2  Female       High school  Black         0                  57
#
#        Citizenship EmploymentStatus                            Industry  \
# 0  Citizen, Native          Retired                                 NaN
# 1  Citizen, Native       Unemployed  Professional and business services
# 2  Citizen, Native         Disabled                                 NaN
#
#       Code              MetroArea
# 0  26620.0         Huntsville, AL
# 1  13820.0  Birmingham-Hoover, AL
# 2  13820.0  Birmingham-Hoover, AL

# %%
tmp.shape
# Out:
# (131302, 16)

# %%
data.shape
# Out:
# (131302, 14)

# %% [markdown]
# #### How many interviewees have a missing value for the new metropolitan area variable? Note that all of these interviewees would have been removed from the merged data frame if we did not include the all.x=TRUE parameter.

# %%
tmp.MetroArea.isnull().sum()
# Out:
# 34238

# %%
#tmp.groupby('MetroArea').size().order()
tmp.groupby('MetroArea').size().sort_values()
# Out:
# MetroArea
# Bowling Green, KY                                       29
# Ocean City, NJ                                          30
# Springfield, OH                                         34
# Bloomington-Normal IL                                   40
# Valdosta, GA                                            42
# Warner Robins, GA                                       42
# Tallahassee, FL                                         43
# Columbia, MO                                            47
# Punta Gorda, FL                                         48
# Midland, TX                                             51
# Niles-Benton Harbor, MI                                 51
# Johnson City, TN                                        52
# Santa Fe, NM                                            52
# Prescott, AZ                                            54
# Vineland-Millville-Bridgeton, NJ                        54
# Hickory-Morgantown-Lenoir, NC                           57
# Madera, CA                                              57
# Joplin, MO                                              59
# Columbus, GA-AL                                         59
# Panama City-Lynn Haven, FL                              59
# Chico, CA                                               60
# Anniston-Oxford, AL                                     61
# Napa, CA                                                61
# Anderson, IN                                            62
# Jacksonville, NC                                        63
# Johnstown, PA                                           63
# Lubbock, TX                                             63
# Monroe, MI                                              63
# Florence, AL                                            63
# Farmington, NM                                          64
#                                                       ...
# Bridgeport-Stamford-Norwalk, CT                        730
# Pittsburgh, PA                                         732
# Tampa-St. Petersburg-Clearwater, FL                    842
# Hartford-West Hartford-East Hartford, CT               885
# San Diego-Carlsbad-San Marcos, CA                      907
# St. Louis, MO-IL                                       956
# Omaha-Council Bluffs, NE-IA                            957
# Kansas City, MO-KS                                     962
# Phoenix-Mesa-Scottsdale, AZ                            971
# Portland-Vancouver-Beaverton, OR-WA                   1089
# Seattle-Tacoma-Bellevue, WA                           1255
# Riverside-San Bernardino, CA                          1290
# Las Vegas-Paradise, NV                                1299
# Detroit-Warren-Livonia, MI                            1354
# San Francisco-Oakland-Fremont, CA                     1386
# Baltimore-Towson, MD                                  1483
# Denver-Aurora, CO                                     1504
# Atlanta-Sandy Springs-Marietta, GA                    1552
# Miami-Fort Lauderdale-Miami Beach, FL                 1554
# Honolulu, HI                                          1576
# Houston-Baytown-Sugar Land, TX                        1649
# Dallas-Fort Worth-Arlington, TX                       1863
# Minneapolis-St Paul-Bloomington, MN-WI                1942
# Boston-Cambridge-Quincy, MA-NH                        2229
# Providence-Fall River-Warwick, MA-RI                  2284
# Chicago-Naperville-Joliet, IN-IN-WI                   2772
# Philadelphia-Camden-Wilmington, PA-NJ-DE              2855
# Los Angeles-Long Beach-Santa Ana, CA                  4102
# Washington-Arlington-Alexandria, DC-VA-MD-WV          4177
# New York-Northern New Jersey-Long Island, NY-NJ-PA    5409
# dtype: int64

# %% [markdown]
# #### Which metropolitan area has the highest proportion of interviewees of Hispanic ethnicity?

# %%
tmp['Hispanic'].head(4)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# Name: Hispanic, dtype: int64

# %%
(tmp.groupby('MetroArea')['Hispanic'].sum()/tmp.groupby('MetroArea')['Hispanic'].count()).sort_values(ascending=False).head(5)
# Out:
# MetroArea
# Laredo, TX                    0.966292
# McAllen-Edinburg-Pharr, TX    0.948718
# Brownsville-Harlingen, TX     0.797468
# El Paso, TX                   0.790984
# El Centro, CA                 0.686869
# Name: Hispanic, dtype: float64

# %% [markdown]
# #### Determine the number of metropolitan areas in the United States from which at least 20% of interviewees are Asian.

# %%
#This is really cool:Though there are many mertroareas with NO asians- we can divide by all metro areas and 
#just get Nans for the ones where there are no asians!
(tmp[tmp.Race=='Asian'].groupby('MetroArea').size()/tmp.groupby('MetroArea').size()).sort_values(ascending=False)
# Out:
# MetroArea
# Honolulu, HI                                          0.501904
# San Francisco-Oakland-Fremont, CA                     0.246753
# San Jose-Sunnyvale-Santa Clara, CA                    0.241791
# Vallejo-Fairfield, CA                                 0.203008
# Fresno, CA                                            0.184818
# Warner Robins, GA                                     0.166667
# Stockton, CA                                          0.155440
# Atlantic City, NJ                                     0.144144
# Sacramento-Arden-Arcade-Roseville, CA                 0.142429
# San Diego-Carlsbad-San Marcos, CA                     0.142227
# Los Angeles-Long Beach-Santa Ana, CA                  0.135056
# Olympia, WA                                           0.131313
# Salinas, CA                                           0.125000
# New York-Northern New Jersey-Long Island, NY-NJ-PA    0.104271
# Seattle-Tacoma-Bellevue, WA                           0.099602
# Visalia-Porterville, CA                               0.090909
# Green Bay, WI                                         0.088235
# La Crosse, WI                                         0.087719
# Ann Arbor, MI                                         0.082353
# Bakersfield, CA                                       0.081633
# Greensboro-High Point, NC                             0.079681
# Las Vegas-Paradise, NV                                0.078522
# Minneapolis-St Paul-Bloomington, MN-WI                0.076725
# Brownsville-Harlingen, TX                             0.075949
# Bloomington-Normal IL                                 0.075000
# Oxnard-Thousand Oaks-Ventura, CA                      0.074906
# Lake Charles, LA                                      0.074074
# Norwich-New London, CT-RI                             0.073892
# Atlanta-Sandy Springs-Marietta, GA                    0.072809
# Washington-Arlington-Alexandria, DC-VA-MD-WV          0.070625
#                                                         ...
# Port St. Lucie-Fort Pierce, FL                             NaN
# Poughkeepsie-Newburgh-Middletown, NY                       NaN
# Pueblo, CO                                                 NaN
# Punta Gorda, FL                                            NaN
# Racine, WI                                                 NaN
# Reading, PA                                                NaN
# Roanoke, VA                                                NaN
# Rockford, IL                                               NaN
# Saginaw-Saginaw Township North, MI                         NaN
# Salem, OR                                                  NaN
# Salisbury, MD                                              NaN
# Santa Fe, NM                                               NaN
# Santa-Cruz-Watsonville, CA                                 NaN
# Scranton-Wilkes Barre, PA                                  NaN
# Shreveport-Bossier City, LA                                NaN
# South Bend-Mishawaka, IN-MI                                NaN
# Spartanburg, SC                                            NaN
# Springfield, MA-CT                                         NaN
# Springfield, OH                                            NaN
# St. Cloud, MN                                              NaN
# Tallahassee, FL                                            NaN
# Tuscaloosa, AL                                             NaN
# Utica-Rome, NY                                             NaN
# Valdosta, GA                                               NaN
# Vero Beach, FL                                             NaN
# Victoria, TX                                               NaN
# Vineland-Millville-Bridgeton, NJ                           NaN
# Waco, TX                                                   NaN
# Waterbury, CT                                              NaN
# Wausau, WI                                                 NaN
# dtype: float64

# %% [markdown]
# #### Determine which metropolitan area has the smallest proportion of interviewees who have received no high school diploma.

# %%
tmp.head()
# Out:
#    PeopleInHousehold Region    State  MetroAreaCode  Age        Married  \
# 0                  1  South  Alabama        26620.0   85        Widowed
# 1                  3  South  Alabama        13820.0   21  Never Married
# 2                  3  South  Alabama        13820.0   37  Never Married
# 3                  3  South  Alabama        13820.0   18  Never Married
# 4                  3  South  Alabama        26620.0   52        Widowed
#
#       Sex               Education   Race  Hispanic  CountryOfBirthCode  \
# 0  Female        Associate degree  White         0                  57
# 1    Male             High school  Black         0                  57
# 2  Female             High school  Black         0                  57
# 3    Male  No high school diploma  Black         0                  57
# 4  Female        Associate degree  White         0                  57
#
#        Citizenship    EmploymentStatus                            Industry  \
# 0  Citizen, Native             Retired                                 NaN
# 1  Citizen, Native          Unemployed  Professional and business services
# 2  Citizen, Native            Disabled                                 NaN
# 3  Citizen, Native  Not in Labor Force                                 NaN
# 4  Citizen, Native            Employed  Professional and business services
#
#       Code              MetroArea
# 0  26620.0         Huntsville, AL
# 1  13820.0  Birmingham-Hoover, AL
# 2  13820.0  Birmingham-Hoover, AL
# 3  13820.0  Birmingham-Hoover, AL
# 4  26620.0         Huntsville, AL

# %%
tmp.Education.value_counts()
# Out:
# High school                30906
# Bachelor's degree          19443
# Some college, no degree    18863
# No high school diploma     16095
# Associate degree            9913
# Master's degree             7816
# Doctorate degree            1516
# Professional degree         1412
# Name: Education, dtype: int64

# %%
#NA groups in GroupBy are automatically excluded. 
((tmp[tmp.Education=='No high school diploma']).groupby('MetroArea').size()/tmp.groupby('MetroArea').size()).sort_values()
# Out:
# MetroArea
# Iowa City, IA                           0.022901
# Bowling Green, KY                       0.034483
# Kalamazoo-Portage, MI                   0.039370
# Champaign-Urbana, IL                    0.040984
# Bremerton-Silverdale, WA                0.045977
# Jacksonville, NC                        0.047619
# Bloomington-Normal IL                   0.050000
# Lawrence, KS                            0.051020
# Salisbury, MD                           0.054054
# Eau Claire, WI                          0.054545
# Gainesville, FL                         0.057143
# Fort Collins-Loveland, CO               0.058252
# Palm Bay-Melbourne-Titusville, FL       0.059524
# Madison, WI                             0.059859
# Fargo, ND-MN                            0.060185
# Altoona, PA                             0.060976
# Billings, MT                            0.065327
# Ocean City, NJ                          0.066667
# Lakeland-Winter Haven, FL               0.067114
# Albany-Schenectady-Troy, NY             0.067164
# Coeur d'Alene, ID                       0.068376
# Asheville, NC                           0.068966
# Akron, OH                               0.069264
# Tallahassee, FL                         0.069767
# Burlington-South Burlington, VT         0.070015
# Oshkosh-Neenah, WI                      0.070588
# Ann Arbor, MI                           0.070588
# Fort Wayne, IN                          0.073529
# Pittsburgh, PA                          0.073770
# Pensacola-Ferry Pass-Brent, FL          0.074766
#                                           ...
# Los Angeles-Long Beach-Santa Ana, CA    0.185763
# Hagerstown-Martinsburg, MD-WV           0.186047
# Joplin, MO                              0.186441
# Panama City-Lynn Haven, FL              0.186441
# Beaumont-Port Author, TX                0.186992
# Anderson, SC                            0.187500
# Bakersfield, CA                         0.187755
# Killeen-Temple-Fort Hood, TX            0.188119
# Harrisonburg, VA                        0.188889
# Hickory-Morgantown-Lenoir, NC           0.192982
# Lafayette, LA                           0.193370
# Youngstown-Warren-Boardman, OH          0.196078
# Stockton, CA                            0.196891
# Brownsville-Harlingen, TX               0.202532
# Vineland-Millville-Bridgeton, NJ        0.203704
# Montgomery, AL                          0.203883
# Tucson, AZ                              0.205298
# Lawton, OK                              0.216495
# Lancaster, PA                           0.217949
# El Paso, TX                             0.225410
# Corpus Christi, TX                      0.227273
# Laredo, TX                              0.235955
# Madera, CA                              0.263158
# Springfield, OH                         0.264706
# Florence, AL                            0.269841
# McAllen-Edinburg-Pharr, TX              0.276923
# Longview, TX                            0.276923
# Salinas, CA                             0.288462
# Kingsport-Bristol, TN-VA                0.298507
# Macon, GA                               0.307692
# dtype: float64

# %% [markdown]
# #### Integrating Country of Birth Data
# Need to merge in the country of birth information from the CountryMap data frame,

# %%
final=tmp.merge(cc,left_on='CountryOfBirthCode',right_on='Code',sort=False,how='left')

# %%
final.drop(['Code_x','Code_y'],axis=1)
# Out:
#         PeopleInHousehold Region    State  MetroAreaCode  Age        Married  \
# 0                       1  South  Alabama        26620.0   85        Widowed
# 1                       3  South  Alabama        13820.0   21  Never Married
# 2                       3  South  Alabama        13820.0   37  Never Married
# 3                       3  South  Alabama        13820.0   18  Never Married
# 4                       3  South  Alabama        26620.0   52        Widowed
# 5                       3  South  Alabama        26620.0   24  Never Married
# 6                       3  South  Alabama        26620.0   26  Never Married
# 7                       2  South  Alabama        33660.0   71       Divorced
# 8                       2  South  Alabama        33660.0   43       Divorced
# 9                       2  South  Alabama        26620.0   52  Never Married
# 10                      2  South  Alabama        26620.0   29  Never Married
# 11                      1  South  Alabama        33860.0   68        Widowed
# 12                      4  South  Alabama        26620.0   24       Divorced
# 13                      4  South  Alabama        26620.0    2            NaN
# 14                      4  South  Alabama        26620.0    4            NaN
# 15                      4  South  Alabama        26620.0   22  Never Married
# 16                      2  South  Alabama        13820.0   40  Never Married
# 17                      2  South  Alabama        13820.0   13            NaN
# 18                      1  South  Alabama        33860.0   42  Never Married
# 19                      2  South  Alabama        33660.0   45       Divorced
# 20                      2  South  Alabama        33660.0   48       Divorced
# 21                      4  South  Alabama        13820.0   78        Widowed
# 22                      4  South  Alabama        13820.0   52  Never Married
# 23                      4  South  Alabama        13820.0   21  Never Married
# 24                      4  South  Alabama        13820.0   35  Never Married
# 25                      3  South  Alabama        33860.0   30        Married
# 26                      3  South  Alabama        33860.0   33        Married
# 27                      3  South  Alabama        33860.0    2            NaN
# 28                      3  South  Alabama        13820.0   60        Widowed
# 29                      3  South  Alabama        13820.0   24  Never Married
# ...                   ...    ...      ...            ...  ...            ...
# 131272                  1   West  Wyoming            NaN   43  Never Married
# 131273                  1   West  Wyoming            NaN   32      Separated
# 131274                  4   West  Wyoming            NaN   34  Never Married
# 131275                  4   West  Wyoming            NaN    9            NaN
# 131276                  4   West  Wyoming            NaN   11            NaN
# 131277                  4   West  Wyoming            NaN   32       Divorced
# 131278                  5   West  Wyoming            NaN   46        Married
# 131279                  5   West  Wyoming            NaN   63        Married
# 131280                  5   West  Wyoming            NaN   13            NaN
# 131281                  5   West  Wyoming            NaN    4            NaN
# 131282                  5   West  Wyoming            NaN    9            NaN
# 131283                  2   West  Wyoming            NaN   19        Married
# 131284                  2   West  Wyoming            NaN   21        Married
# 131285                  1   West  Wyoming            NaN   68       Divorced
# 131286                  2   West  Wyoming            NaN   60        Married
# 131287                  2   West  Wyoming            NaN   61        Married
# 131288                  2   West  Wyoming            NaN   80        Married
# 131289                  2   West  Wyoming            NaN   80        Married
# 131290                  2   West  Wyoming            NaN   56        Married
# 131291                  2   West  Wyoming            NaN   59        Married
# 131292                  2   West  Wyoming            NaN   52        Widowed
# 131293                  2   West  Wyoming            NaN   27  Never Married
# 131294                  5   West  Wyoming            NaN   39       Divorced
# 131295                  5   West  Wyoming            NaN   10            NaN
# 131296                  5   West  Wyoming            NaN   14            NaN
# 131297                  5   West  Wyoming            NaN   17  Never Married
# 131298                  5   West  Wyoming            NaN   37       Divorced
# 131299                  3   West  Wyoming            NaN   58        Married
# 131300                  3   West  Wyoming            NaN   53        Married
# 131301                  3   West  Wyoming            NaN   14            NaN
#
#            Sex                Education              Race  Hispanic  \
# 0       Female         Associate degree             White         0
# 1         Male              High school             Black         0
# 2       Female              High school             Black         0
# 3         Male   No high school diploma             Black         0
# 4       Female         Associate degree             White         0
# 5         Male        Bachelor's degree             White         0
# 6         Male              High school             White         0
# 7       Female              High school             White         0
# 8         Male              High school             White         0
# 9         Male        Bachelor's degree             White         0
# 10        Male        Bachelor's degree             White         0
# 11      Female   No high school diploma             Black         0
# 12        Male   No high school diploma             White         0
# 13      Female                      NaN             White         0
# 14        Male                      NaN             White         0
# 15      Female  Some college, no degree             White         0
# 16      Female         Associate degree             Black         0
# 17      Female                      NaN             Black         0
# 18      Female         Doctorate degree             Black         0
# 19      Female        Bachelor's degree  Pacific Islander         0
# 20        Male              High school  Pacific Islander         0
# 21      Female              High school             Black         0
# 22      Female              High school             Black         0
# 23      Female  Some college, no degree             Black         0
# 24      Female              High school             Black         0
# 25      Female  Some college, no degree             White         0
# 26        Male  Some college, no degree             White         0
# 27      Female                      NaN             White         0
# 28      Female         Associate degree             Black         0
# 29        Male  Some college, no degree             Black         0
# ...        ...                      ...               ...       ...
# 131272  Female   No high school diploma             White         0
# 131273    Male   No high school diploma             White         1
# 131274    Male              High school             White         0
# 131275  Female                      NaN             White         1
# 131276  Female                      NaN             White         1
# 131277  Female         Associate degree             White         1
# 131278  Female         Associate degree             White         0
# 131279    Male              High school             White         0
# 131280  Female                      NaN             White         0
# 131281  Female                      NaN             White         0
# 131282  Female                      NaN             White         0
# 131283  Female   No high school diploma             White         1
# 131284    Male              High school             White         1
# 131285    Male              High school             White         0
# 131286    Male              High school             White         0
# 131287  Female              High school             White         0
# 131288  Female  Some college, no degree             Black         0
# 131289    Male              High school             Black         0
# 131290    Male  Some college, no degree             White         0
# 131291  Female        Bachelor's degree             White         0
# 131292  Female  Some college, no degree             White         0
# 131293    Male              High school             White         0
# 131294  Female         Associate degree             White         0
# 131295  Female                      NaN             White         0
# 131296    Male                      NaN             White         0
# 131297    Male   No high school diploma             White         0
# 131298    Male              High school             White         0
# 131299    Male        Bachelor's degree             White         0
# 131300  Female         Associate degree             White         0
# 131301  Female                      NaN             White         0
#
#         CountryOfBirthCode           Citizenship    EmploymentStatus  \
# 0                       57       Citizen, Native             Retired
# 1                       57       Citizen, Native          Unemployed
# 2                       57       Citizen, Native            Disabled
# 3                       57       Citizen, Native  Not in Labor Force
# 4                       57       Citizen, Native            Employed
# 5                       57       Citizen, Native            Employed
# 6                       57       Citizen, Native            Employed
# 7                       57       Citizen, Native            Employed
# 8                       57       Citizen, Native  Not in Labor Force
# 9                       57       Citizen, Native            Employed
# 10                      57       Citizen, Native            Employed
# 11                      57       Citizen, Native             Retired
# 12                      57       Citizen, Native            Employed
# 13                      57       Citizen, Native                 NaN
# 14                      57       Citizen, Native                 NaN
# 15                      57       Citizen, Native            Employed
# 16                     341  Citizen, Naturalized            Employed
# 17                      57       Citizen, Native                 NaN
# 18                      57       Citizen, Native            Employed
# 19                     233       Citizen, Native            Employed
# 20                      57       Citizen, Native            Employed
# 21                      57       Citizen, Native             Retired
# 22                      57       Citizen, Native            Employed
# 23                      57       Citizen, Native  Not in Labor Force
# 24                      57       Citizen, Native            Disabled
# 25                     362           Non-Citizen            Employed
# 26                      57       Citizen, Native            Employed
# 27                      57       Citizen, Native                 NaN
# 28                      57       Citizen, Native  Not in Labor Force
# 29                      57       Citizen, Native            Employed
# ...                    ...                   ...                 ...
# 131272                  57       Citizen, Native            Employed
# 131273                  57       Citizen, Native            Employed
# 131274                  57       Citizen, Native            Employed
# 131275                  57       Citizen, Native                 NaN
# 131276                  57       Citizen, Native                 NaN
# 131277                  57       Citizen, Native            Employed
# 131278                  57       Citizen, Native            Employed
# 131279                  57       Citizen, Native            Employed
# 131280                  57       Citizen, Native                 NaN
# 131281                  57       Citizen, Native                 NaN
# 131282                  57       Citizen, Native                 NaN
# 131283                  57       Citizen, Native  Not in Labor Force
# 131284                  57       Citizen, Native                 NaN
# 131285                  57       Citizen, Native            Employed
# 131286                  57       Citizen, Native             Retired
# 131287                  57       Citizen, Native            Employed
# 131288                  57       Citizen, Native             Retired
# 131289                  57       Citizen, Native             Retired
# 131290                  57       Citizen, Native            Employed
# 131291                  57       Citizen, Native             Retired
# 131292                  57       Citizen, Native            Disabled
# 131293                  57       Citizen, Native          Unemployed
# 131294                  57       Citizen, Native  Not in Labor Force
# 131295                  57       Citizen, Native                 NaN
# 131296                  57       Citizen, Native                 NaN
# 131297                  57       Citizen, Native  Not in Labor Force
# 131298                  57       Citizen, Native            Employed
# 131299                  57       Citizen, Native            Employed
# 131300                  57       Citizen, Native  Not in Labor Force
# 131301                  57       Citizen, Native                 NaN
#
#                                   Industry              MetroArea  \
# 0                                      NaN         Huntsville, AL
# 1       Professional and business services  Birmingham-Hoover, AL
# 2                                      NaN  Birmingham-Hoover, AL
# 3                                      NaN  Birmingham-Hoover, AL
# 4       Professional and business services         Huntsville, AL
# 5          Educational and health services         Huntsville, AL
# 6             Transportation and utilities         Huntsville, AL
# 7          Educational and health services             Mobile, AL
# 8                                      NaN             Mobile, AL
# 9                    Public administration         Huntsville, AL
# 10                 Leisure and hospitality         Huntsville, AL
# 11                                     NaN         Montgomery, AL
# 12      Professional and business services         Huntsville, AL
# 13                                     NaN         Huntsville, AL
# 14                                     NaN         Huntsville, AL
# 15         Educational and health services         Huntsville, AL
# 16         Educational and health services  Birmingham-Hoover, AL
# 17                                     NaN  Birmingham-Hoover, AL
# 18         Educational and health services         Montgomery, AL
# 19         Educational and health services             Mobile, AL
# 20                   Public administration             Mobile, AL
# 21                                     NaN  Birmingham-Hoover, AL
# 22         Educational and health services  Birmingham-Hoover, AL
# 23                                     NaN  Birmingham-Hoover, AL
# 24                                     NaN  Birmingham-Hoover, AL
# 25      Professional and business services         Montgomery, AL
# 26                                   Trade         Montgomery, AL
# 27                                     NaN         Montgomery, AL
# 28                                     NaN  Birmingham-Hoover, AL
# 29      Professional and business services  Birmingham-Hoover, AL
# ...                                    ...                    ...
# 131272                               Trade                    NaN
# 131273                       Manufacturing                    NaN
# 131274                       Manufacturing                    NaN
# 131275                                 NaN                    NaN
# 131276                                 NaN                    NaN
# 131277     Educational and health services                    NaN
# 131278  Professional and business services                    NaN
# 131279                         Information                    NaN
# 131280                                 NaN                    NaN
# 131281                                 NaN                    NaN
# 131282                                 NaN                    NaN
# 131283                                 NaN                    NaN
# 131284                                 NaN                    NaN
# 131285                               Trade                    NaN
# 131286                                 NaN                    NaN
# 131287               Public administration                    NaN
# 131288                                 NaN                    NaN
# 131289                                 NaN                    NaN
# 131290               Public administration                    NaN
# 131291                                 NaN                    NaN
# 131292                                 NaN                    NaN
# 131293  Professional and business services                    NaN
# 131294                                 NaN                    NaN
# 131295                                 NaN                    NaN
# 131296                                 NaN                    NaN
# 131297                                 NaN                    NaN
# 131298                              Mining                    NaN
# 131299                           Financial                    NaN
# 131300                                 NaN                    NaN
# 131301                                 NaN                    NaN
#
#                     Country
# 0             United States
# 1             United States
# 2             United States
# 3             United States
# 4             United States
# 5             United States
# 6             United States
# 7             United States
# 8             United States
# 9             United States
# 10            United States
# 11            United States
# 12            United States
# 13            United States
# 14            United States
# 15            United States
# 16      Trinidad and Tobago
# 17            United States
# 18            United States
# 19              Philippines
# 20            United States
# 21            United States
# 22            United States
# 23            United States
# 24            United States
# 25                   Brazil
# 26            United States
# 27            United States
# 28            United States
# 29            United States
# ...                     ...
# 131272        United States
# 131273        United States
# 131274        United States
# 131275        United States
# 131276        United States
# 131277        United States
# 131278        United States
# 131279        United States
# 131280        United States
# 131281        United States
# 131282        United States
# 131283        United States
# 131284        United States
# 131285        United States
# 131286        United States
# 131287        United States
# 131288        United States
# 131289        United States
# 131290        United States
# 131291        United States
# 131292        United States
# 131293        United States
# 131294        United States
# 131295        United States
# 131296        United States
# 131297        United States
# 131298        United States
# 131299        United States
# 131300        United States
# 131301        United States
#
# [131302 rows x 16 columns]

# %% [markdown]
# #### How many interviewees have a missing value for the new country of birth variable?

# %%
final['Country'].isnull().sum()
# Out:
# 176

# %% [markdown]
# #### Among all interviewees born outside of North America, which country was the most common place of birth?

# %%
(final[final.Country != 'United States'])['Country'].value_counts().head()
# Out:
# Mexico         3921
# Philippines     839
# India           770
# China           581
# Puerto Rico     518
# Name: Country, dtype: int64

# %% [markdown]
# #### What proportion of the interviewees from the "New York-Northern New Jersey-Long Island, NY-NJ-PA" metropolitan area have a country of birth that is not the United States?

# %%
float(final[final.MetroArea=='New York-Northern New Jersey-Long Island, NY-NJ-PA'][final.Country != 'United States']['MetroAreaCode'].count())/final[final.MetroArea=='New York-Northern New Jersey-Long Island, NY-NJ-PA']['MetroAreaCode'].count()
# Out:
# /Users/priyadesai/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# 0.30929931595489

# %% [markdown]
# #### Which metropolitan area has the largest number (note -- not proportion) of interviewees with a country of birth:
# * in India?
# * in Brazil?
# * in Somalia?

# %%
(final[final.Country=='India']).groupby('MetroArea').size().sort_values(ascending=False).head()
# Out:
# MetroArea
# New York-Northern New Jersey-Long Island, NY-NJ-PA    96
# Washington-Arlington-Alexandria, DC-VA-MD-WV          50
# Philadelphia-Camden-Wilmington, PA-NJ-DE              32
# Chicago-Naperville-Joliet, IN-IN-WI                   31
# Detroit-Warren-Livonia, MI                            30
# dtype: int64

# %%
final[final.Country=='Brazil'].groupby('MetroArea').size().sort_values(ascending=False).head()
# Out:
# MetroArea
# Boston-Cambridge-Quincy, MA-NH                        18
# Miami-Fort Lauderdale-Miami Beach, FL                 16
# Los Angeles-Long Beach-Santa Ana, CA                   9
# Washington-Arlington-Alexandria, DC-VA-MD-WV           8
# New York-Northern New Jersey-Long Island, NY-NJ-PA     7
# dtype: int64

# %%
final[final.Country=='Somalia'].groupby('MetroArea').size().sort_values(ascending=False).head()
# Out:
# MetroArea
# Minneapolis-St Paul-Bloomington, MN-WI    17
# St. Cloud, MN                              7
# Seattle-Tacoma-Bellevue, WA                7
# Phoenix-Mesa-Scottsdale, AZ                7
# Fargo, ND-MN                               5
# dtype: int64
